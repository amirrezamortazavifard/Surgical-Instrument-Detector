# %%
# !cd drive/MyDrive/
# Out:
# /bin/bash: line 1: cd: drive/MyDrive/: No such file or directory

# %%
# !ls

# %%
# !unzip data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/images/test/pinca294.jpg
#   inflating: data/images/test/pinca297.jpg
#   inflating: data/images/test/pinca299.jpg
#   inflating: data/images/test/pinca300.jpg
#   inflating: data/images/test/pinca301.jpg
#   inflating: data/images/test/pinca306.jpg
#   inflating: data/images/test/pinca310.jpg
#   inflating: data/images/test/pinca311.jpg
#   inflating: data/images/test/pinca315.jpg
#   inflating: data/images/test/pinca316.jpg
#   inflating: data/images/test/pinca317.jpg
#   inflating: data/images/test/pinca319.jpg
#   inflating: data/images/test/pinca320.jpg
#   inflating: data/images/test/pinca323.jpg
#   inflating: data/images/test/pinca326.jpg
#   inflating: data/images/test/pinca328.jpg
#   inflating: data/images/test/pinca330.jpg
#   inflating: data/images/test/pinca331.jpg
#   inflating: data/images/test/pinca34.jpg
#   inflating: data/images/test/pinca343.jpg
#   inflating: data/images/test/pinca344.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 41.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 69.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !yolo train data=data.yaml model=yolo11l.pt epochs=100 lr0=0.01
# Out:
# ...
# 100% 49.0M/49.0M [00:00<00:00, 223MB/s]
# Ultralytics 8.3.154 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
